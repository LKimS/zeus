# %%
import pypsa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from cartopy import crs as ccrs
from pypsa.plot import add_legend_circles, add_legend_lines, add_legend_patches
import cartopy

# %%
n = pypsa.Network('base.nc')

n
# Out:
# WARNING:pypsa.io:Importing network from PyPSA version v0.31.1 while current version is v0.32.0. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.io:Imported network base.nc has buses, carriers, lines, links, shapes, transformers
# PyPSA Network 'PyPSA-Eur (osm-prebuilt v0.4)'
# Components:
#  - Bus: 723
#  - Carrier: 2
#  - Line: 850
#  - Link: 22
#  - Shape: 6
#  - Transformer: 75
# Snapshots: 8784

# %%
n.iplot()
# Out:
# {'data': [{'x': Bus
#    1486    25.0344
#    1487    21.6301
#    1488    25.3681
#    1489    24.5495
#    1490    23.9749
#             ...
#    6050     6.8684
#    6052    14.8414
#    6054    25.3686
#    6055     8.0423
#    6056     6.6530
#    Name: x, Length: 723, dtype: float64,
#    'y': Bus
#    1486    60.2780
#    1487    61.1808
#    1488    60.3773
#    1489    60.2046
#    1490    61.4795
#             ...
#    6050    58.2825
#    6052    56.1533
#    6054    60.3765
#    6055    58.2213
#    6056    59.5307
#    Name: y, Length: 723, dtype: float64,
#    'text': Index(['Bus 1486', 'Bus 1487', 'Bus 1488', 'Bus 1489', 'Bus 1490', 'Bus 1491',
#           'Bus 1492', 'Bus 1493', 'Bus 1494', 'Bus 1495',
#           ...
#           'Bus 6036', 'Bus 6037', 'Bus 6040', 'Bus 6041', 'Bus 6045', 'Bus 6050',
#           'Bus 6052', 'Bus 6054', 'Bus 6055', 'Bus 6056'],
#          dtype='object', name='Bus', length=723),
#    'mode': 'markers',
#    'hoverinfo': 'text',
#    'opacity': 1,
#    'marker': {'color': 'cadetblue', 'size': 10},
#    'type': 'scatter'},
#   {'x': Line
#    18617948     27.19245
#    22688336     25.61870
#    23082952     25.18635
#    23083034     23.43835
#    23804410     24.07070
#                   ...
#    188965945    11.92210
#    287684721    11.87415
#    292593505    17.47490
#    585475863    11.67435
#    610564182    14.18605
#    Length: 850, dtype: float64,
#    'y': Line
#    18617948     68.17545
#    22688336     64.80895
#    23082952     64.33280
#    23083034     62.90950
#    23804410     62.25600
#                   ...
#    188965945    59.34470
#    287684721    63.10385
#    292593505    67.90540
#    585475863    58.87485
#    610564182    65.90735
#    Length: 850, dtype: float64,
#    'text': Index(['Line 18617948', 'Line 22688336', 'Line 23082952', 'Line 23083034',
#           'Line 23804410', 'Line 25197153-1', 'Line 25619159', 'Line 25619189',
#           'Line 26164596', 'Line 26619354',
#           ...
#           'Line 260616868', 'Line 763346033', 'Line 47317779', 'Line 400567450',
#           'Line 1025521314', 'Line 188965945', 'Line 287684721', 'Line 292593505',
#           'Line 585475863', 'Line 610564182'],
#          dtype='object', name='Line', length=850),
#    'mode': 'markers',
#    'hoverinfo': 'text',
#    'marker': {'opacity': 0.0},
#    'type': 'scatter'},
#   {'x': Transformer
#    transf_1132_0    26.0487
#    transf_1135_0    25.4520
#    transf_1145_0    25.3455
#    transf_1150_0    21.3695
#    transf_1152_0    27.1438
#                      ...
#    transf_4047_0    10.9054
#    transf_4503_0    11.8177
#    transf_4506_0    12.0601
#    transf_4537_0    13.9912
#    transf_4623_0    17.4650
#    Length: 75, dtype: float64,
#    'y': Transformer
#    transf_1132_0    64.8473
#    transf_1135_0    64.1232
#    transf_1145_0    66.2703
#    transf_1150_0    62.2781
#    transf_1152_0    66.3400
#                      ...
#    transf_4047_0    59.9891
#    transf_4503_0    59.3380
#    transf_4506_0    63.1772
#    transf_4537_0    63.3407
#    transf_4623_0    68.0822
#    Length: 75, dtype: float64,
#    'text': Index(['Transformer transf_1132_0', 'Transformer transf_1135_0',
#           'Transformer transf_1145_0', 'Transformer transf_1150_0',
#           'Transformer transf_1152_0', 'Transformer transf_2495_0',
#           'Transformer transf_2497_0', 'Transformer transf_2499_0',
#           'Transformer transf_2502_0', 'Transformer transf_2504_0',
#           'Transformer transf_2505_0', 'Transformer transf_2510_0',
#           'Transformer transf_2515_0', 'Transformer transf_2517_0',
#           'Transformer transf_2520_0', 'Transformer transf_2530_0',
#           'Transformer transf_2531_0', 'Transformer transf_2534_0',
#           'Transformer transf_2535_0', 'Transformer transf_2540_0',
#           'Transformer transf_2541_0', 'Transformer transf_2544_0',
#           'Transformer transf_2551_0', 'Transformer transf_2575_0',
#           'Transformer transf_2883_0', 'Transformer transf_2884_0',
#           'Transformer transf_2885_0', 'Transformer transf_2887_0',
#           'Transformer transf_2890_0', 'Transformer transf_2909_0',
#           'Transformer transf_2910_0', 'Transformer transf_2912_0',
#           'Transformer transf_2917_0', 'Transformer transf_2922_0',
#           'Transformer transf_2922_1', 'Transformer transf_2922_2',
#           'Transformer transf_2925_0', 'Transformer transf_2929_0',
#           'Transformer transf_2938_0', 'Transformer transf_2939_0',
#           'Transformer transf_2949_0', 'Transformer transf_2951_0',
#           'Transformer transf_2963_0', 'Transformer transf_2973_0',
#           'Transformer transf_2975_0', 'Transformer transf_2989_0',
#           'Transformer transf_3247_0', 'Transformer transf_3257_0',
#           'Transformer transf_3261_0', 'Transformer transf_3263_0',
#           'Transformer transf_3267_0', 'Transformer transf_3267_1',
#           'Transformer transf_3271_0', 'Transformer transf_3285_0',
#           'Transformer transf_3286_0', 'Transformer transf_3292_0',
#           'Transformer transf_3301_0', 'Transformer transf_3306_0',
#           'Transformer transf_3310_0', 'Transformer transf_3312_0',
#           'Transformer transf_3665_0', 'Transformer transf_3666_0',
#           'Transformer transf_3702_0', 'Transformer transf_3703_0',
#           'Transformer transf_3719_0', 'Transformer transf_3722_0',
#           'Transformer transf_3733_0', 'Transformer transf_3852_0',
#           'Transformer transf_4030_0', 'Transformer transf_4033_0',
#           'Transformer transf_4047_0', 'Transformer transf_4503_0',
#           'Transformer transf_4506_0', 'Transformer transf_4537_0',
#           'Transformer transf_4623_0'],
#          dtype='object', name='Transformer'),
#    'mode': 'markers',
#    'hoverinfo': 'text',
#    'marker': {'opacity': 0.0},
#    'type': 'scatter'},
#   {'x': Link
#    relation/3392001                 17.42175
#    relation/8184633                 14.12850
#    relation/3391954                 19.34440
#    relation/8184631                 19.88050
#    converter/relation/3392001_1     16.65390
#    converter/relation/8184633_0     13.60210
#    converter/relation/8184633_1     14.65700
#    converter/relation/3918230_1     13.14630
#    converter/relation/9965201_1      6.86490
#    converter/relation/16213216_1     6.74180
#    converter/relation/3391931_1      7.90165
#    converter/relation/8184629_1     12.11110
#    converter/relation/8184632_1      7.97185
#    converter/relation/6886400_1     25.36835
#    converter/relation/8184630_1     24.55040
#    converter/relation/3391954_0     21.62815
#    converter/relation/3391954_1     17.06175
#    converter/relation/8184631_0     18.14540
#    converter/relation/8184631_1     21.62765
#    converter/relation/13295785_0     6.64690
#    converter/relation/8185455_1     15.85610
#    converter/relation/3392010_1     14.83925
#    dtype: float64,
#    'y': Link
#    relation/3392001                 57.65795
#    relation/8184633                 56.78955
#    relation/3391954                 60.78950
#    relation/8184631                 60.77825
#    converter/relation/3392001_1     57.57235
#    converter/relation/8184633_0     55.83165
#    converter/relation/8184633_1     57.74975
#    converter/relation/3918230_1     55.50155
#    converter/relation/9965201_1     58.27850
#    converter/relation/16213216_1    58.66490
#    converter/relation/3391931_1     58.26085
#    converter/relation/8184629_1     57.60760
#    converter/relation/8184632_1     58.24100
#    converter/relation/6886400_1     60.37690
#    converter/relation/8184630_1     60.20420
#    converter/relation/3391954_0     61.16700
#    converter/relation/3391954_1     60.42535
#    converter/relation/8184631_0     60.40160
#    converter/relation/8184631_1     61.16650
#    converter/relation/13295785_0    59.53595
#    converter/relation/8185455_1     56.76765
#    converter/relation/3392010_1     56.15290
#    dtype: float64,
#    'text': Index(['Link relation/3392001', 'Link relation/8184633',
#           'Link relation/3391954', 'Link relation/8184631',
#           'Link converter/relation/3392001_1',
#           'Link converter/relation/8184633_0',
#           'Link converter/relation/8184633_1',
#           'Link converter/relation/3918230_1',
#           'Link converter/relation/9965201_1',
#           'Link converter/relation/16213216_1',
#           'Link converter/relation/3391931_1',
#           'Link converter/relation/8184629_1',
#           'Link converter/relation/8184632_1',
#           'Link converter/relation/6886400_1',
#           'Link converter/relation/8184630_1',
#           'Link converter/relation/3391954_0',
#           'Link converter/relation/3391954_1',
#           'Link converter/relation/8184631_0',
#           'Link converter/relation/8184631_1',
#           'Link converter/relation/13295785_0',
#           'Link converter/relation/8185455_1',
#           'Link converter/relation/3392010_1'],
#          dtype='object', name='Link'),
#    'mode': 'markers',
#    'hoverinfo': 'text',
#    'marker': {'opacity': 0.0},
#    'type': 'scatter'}],
#  'layout': {'title': '',
#   'hovermode': 'closest',
#   'showlegend': False,
#   'shapes': [{'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.8019,
#     'y0': 67.6954,
#     'x1': 27.583,
#     'y1': 68.6555,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.7399,
#     'y0': 64.9249,
#     'x1': 25.4975,
#     'y1': 64.693,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.8752,
#     'y0': 63.9726,
#     'x1': 25.4975,
#     'y1': 64.693,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.7102,
#     'y0': 62.7865,
#     'x1': 24.1665,
#     'y1': 63.0325,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.9749,
#     'y0': 61.4795,
#     'x1': 24.1665,
#     'y1': 63.0325,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.0824,
#     'y0': 63.8013,
#     'x1': 23.5105,
#     'y1': 63.974,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.0344,
#     'y0': 60.278,
#     'x1': 24.6665,
#     'y1': 60.2287,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.0344,
#     'y0': 60.278,
#     'x1': 24.923,
#     'y1': 60.3582,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.7399,
#     'y0': 64.9249,
#     'x1': 26.5585,
#     'y1': 65.8205,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.3681,
#     'y0': 60.3773,
#     'x1': 25.5986,
#     'y1': 60.4302,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.1665,
#     'y0': 63.0325,
#     'x1': 25.8476,
#     'y1': 62.359,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.586,
#     'y0': 61.1511,
#     'x1': 23.5752,
#     'y1': 60.8014,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.4849,
#     'y0': 60.7662,
#     'x1': 24.2446,
#     'y1': 60.7742,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.8476,
#     'y0': 62.359,
#     'x1': 27.6709,
#     'y1': 62.2121,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.2125,
#     'y0': 64.1054,
#     'x1': 27.5211,
#     'y1': 63.1881,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.3663,
#     'y0': 61.7279,
#     'x1': 27.6709,
#     'y1': 62.2121,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.2848,
#     'y0': 61.3879,
#     'x1': 23.4331,
#     'y1': 61.4667,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.0951,
#     'y0': 62.8011,
#     'x1': 25.2954,
#     'y1': 63.8066,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.1286,
#     'y0': 61.8927,
#     'x1': 25.1438,
#     'y1': 62.2794,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.2725,
#     'y0': 60.1663,
#     'x1': 24.5495,
#     'y1': 60.2046,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.3445,
#     'y0': 60.3712,
#     'x1': 26.5954,
#     'y1': 60.8383,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.7399,
#     'y0': 64.9249,
#     'x1': 26.0492,
#     'y1': 64.8478,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6301,
#     'y0': 61.1808,
#     'x1': 22.4996,
#     'y1': 60.5234,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.7135,
#     'y0': 65.9294,
#     'x1': 25.1231,
#     'y1': 66.1549,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.5621,
#     'y0': 64.4237,
#     'x1': 25.0679,
#     'y1': 64.681,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.5954,
#     'y0': 60.8383,
#     'x1': 26.9064,
#     'y1': 60.5989,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.9749,
#     'y0': 61.4795,
#     'x1': 24.1556,
#     'y1': 61.6151,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9444,
#     'y0': 60.4939,
#     'x1': 25.3681,
#     'y1': 60.3773,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.9101,
#     'y0': 60.022,
#     'x1': 23.0904,
#     'y1': 60.3415,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.586,
#     'y0': 61.1511,
#     'x1': 23.5469,
#     'y1': 61.4037,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.0198,
#     'y0': 61.4767,
#     'x1': 21.434,
#     'y1': 61.6302,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.8926,
#     'y0': 61.7918,
#     'x1': 21.9695,
#     'y1': 61.7097,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.1433,
#     'y0': 66.3395,
#     'x1': 27.2994,
#     'y1': 66.3975,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.1438,
#     'y0': 62.2794,
#     'x1': 25.8476,
#     'y1': 62.359,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.586,
#     'y0': 61.1511,
#     'x1': 22.4477,
#     'y1': 61.1588,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.526,
#     'y0': 65.8883,
#     'x1': 25.6944,
#     'y1': 65.2668,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.346,
#     'y0': 66.2708,
#     'x1': 23.8285,
#     'y1': 66.1725,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.37,
#     'y0': 62.2786,
#     'x1': 21.8926,
#     'y1': 61.7918,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.5723,
#     'y0': 64.2453,
#     'x1': 26.0482,
#     'y1': 64.8468,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.1632,
#     'y0': 65.7718,
#     'x1': 24.526,
#     'y1': 65.8883,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.0344,
#     'y0': 60.278,
#     'x1': 25.3681,
#     'y1': 60.3773,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9492,
#     'y0': 60.7517,
#     'x1': 24.9574,
#     'y1': 60.654,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9574,
#     'y0': 60.654,
#     'x1': 24.9492,
#     'y1': 60.7517,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.5469,
#     'y0': 61.4037,
#     'x1': 23.7799,
#     'y1': 61.4017,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.7799,
#     'y0': 61.4017,
#     'x1': 23.9749,
#     'y1': 61.4795,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.5469,
#     'y0': 61.4037,
#     'x1': 23.7799,
#     'y1': 61.4017,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.7799,
#     'y0': 61.4017,
#     'x1': 23.9749,
#     'y1': 61.4795,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9015,
#     'y0': 60.6057,
#     'x1': 24.9574,
#     'y1': 60.654,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6301,
#     'y0': 61.1808,
#     'x1': 22.0198,
#     'y1': 61.4767,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.4626,
#     'y0': 61.2415,
#     'x1': 21.6301,
#     'y1': 61.1808,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.4626,
#     'y0': 61.2415,
#     'x1': 21.6301,
#     'y1': 61.1808,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.4626,
#     'y0': 61.2415,
#     'x1': 21.6301,
#     'y1': 61.1808,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6301,
#     'y0': 61.1808,
#     'x1': 21.7552,
#     'y1': 61.1574,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6301,
#     'y0': 61.1808,
#     'x1': 21.7552,
#     'y1': 61.1574,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.0198,
#     'y0': 61.4767,
#     'x1': 21.6301,
#     'y1': 61.1808,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.9695,
#     'y0': 61.7097,
#     'x1': 22.0198,
#     'y1': 61.4767,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.9695,
#     'y0': 61.7097,
#     'x1': 22.0198,
#     'y1': 61.4767,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.7446,
#     'y0': 62.7944,
#     'x1': 21.7263,
#     'y1': 62.7399,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6469,
#     'y0': 62.472,
#     'x1': 21.7144,
#     'y1': 62.6851,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.8711,
#     'y0': 63.0557,
#     'x1': 21.7446,
#     'y1': 62.7944,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.7263,
#     'y0': 62.7399,
#     'x1': 21.7144,
#     'y1': 62.6851,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.002,
#     'y0': 63.7306,
#     'x1': 23.0824,
#     'y1': 63.8013,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.6991,
#     'y0': 60.7594,
#     'x1': 24.4849,
#     'y1': 60.7662,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.2754,
#     'y0': 60.2741,
#     'x1': 24.9015,
#     'y1': 60.6057,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.6415,
#     'y0': 63.501,
#     'x1': 23.002,
#     'y1': 63.7306,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.5718,
#     'y0': 63.4455,
#     'x1': 22.6415,
#     'y1': 63.501,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.1556,
#     'y0': 61.6151,
#     'x1': 25.1286,
#     'y1': 61.8927,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.5211,
#     'y0': 63.1881,
#     'x1': 27.6709,
#     'y1': 62.2121,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.187,
#     'y0': 64.7836,
#     'x1': 27.2125,
#     'y1': 64.1054,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.1665,
#     'y0': 63.0325,
#     'x1': 24.8752,
#     'y1': 63.9726,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.1665,
#     'y0': 63.0325,
#     'x1': 24.8752,
#     'y1': 63.9726,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.8711,
#     'y0': 63.0557,
#     'x1': 22.5044,
#     'y1': 63.3875,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.345,
#     'y0': 66.2698,
#     'x1': 25.5418,
#     'y1': 66.4251,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.4996,
#     'y0': 60.5234,
#     'x1': 23.0904,
#     'y1': 60.3415,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.7102,
#     'y0': 62.7865,
#     'x1': 21.8711,
#     'y1': 63.0557,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.8752,
#     'y0': 63.9726,
#     'x1': 25.4975,
#     'y1': 64.693,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.4331,
#     'y0': 61.4667,
#     'x1': 23.5469,
#     'y1': 61.4037,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.0482,
#     'y0': 64.8468,
#     'x1': 26.7079,
#     'y1': 64.5796,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.7079,
#     'y0': 64.5796,
#     'x1': 28.415,
#     'y1': 64.5911,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.526,
#     'y0': 65.8883,
#     'x1': 25.346,
#     'y1': 66.2708,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.6944,
#     'y0': 65.2668,
#     'x1': 26.0492,
#     'y1': 64.8478,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.7579,
#     'y0': 60.4327,
#     'x1': 25.5986,
#     'y1': 60.4302,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.5986,
#     'y0': 60.4302,
#     'x1': 25.7579,
#     'y1': 60.4327,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.9849,
#     'y0': 60.4744,
#     'x1': 25.7579,
#     'y1': 60.4327,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.7579,
#     'y0': 60.4327,
#     'x1': 25.9849,
#     'y1': 60.4744,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.3445,
#     'y0': 60.3712,
#     'x1': 25.9849,
#     'y1': 60.4744,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.9849,
#     'y0': 60.4744,
#     'x1': 26.9064,
#     'y1': 60.5989,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9444,
#     'y0': 60.4939,
#     'x1': 24.9015,
#     'y1': 60.6057,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.6488,
#     'y0': 60.4359,
#     'x1': 24.2089,
#     'y1': 60.5513,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.923,
#     'y0': 60.3582,
#     'x1': 24.7463,
#     'y1': 60.413,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.7463,
#     'y0': 60.413,
#     'x1': 24.6488,
#     'y1': 60.4359,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.5954,
#     'y0': 60.8383,
#     'x1': 28.0302,
#     'y1': 61.0187,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.9101,
#     'y0': 60.022,
#     'x1': 24.2725,
#     'y1': 60.1663,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.2754,
#     'y0': 60.2741,
#     'x1': 24.2725,
#     'y1': 60.1663,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.586,
#     'y0': 61.1511,
#     'x1': 22.2848,
#     'y1': 61.3879,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.586,
#     'y0': 61.1511,
#     'x1': 22.4477,
#     'y1': 61.1588,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.1231,
#     'y0': 66.1549,
#     'x1': 25.345,
#     'y1': 66.2698,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9015,
#     'y0': 60.6057,
#     'x1': 24.9574,
#     'y1': 60.654,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.583,
#     'y0': 68.6555,
#     'x1': 27.2273,
#     'y1': 69.8435,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.4477,
#     'y0': 61.1588,
#     'x1': 22.2524,
#     'y1': 61.1718,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.4477,
#     'y0': 61.1588,
#     'x1': 22.2524,
#     'y1': 61.1718,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.2524,
#     'y0': 61.1718,
#     'x1': 21.7552,
#     'y1': 61.1574,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.2524,
#     'y0': 61.1718,
#     'x1': 21.7552,
#     'y1': 61.1574,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.5752,
#     'y0': 60.8014,
#     'x1': 24.2089,
#     'y1': 60.5513,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.3681,
#     'y0': 60.3773,
#     'x1': 25.5986,
#     'y1': 60.4302,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 28.0302,
#     'y0': 61.0187,
#     'x1': 27.3663,
#     'y1': 61.7279,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.6709,
#     'y0': 62.2121,
#     'x1': 27.3663,
#     'y1': 61.7279,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.9749,
#     'y0': 61.4795,
#     'x1': 24.9492,
#     'y1': 60.7517,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.2848,
#     'y0': 61.3879,
#     'x1': 22.0198,
#     'y1': 61.4767,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.0198,
#     'y0': 61.4767,
#     'x1': 22.2848,
#     'y1': 61.3879,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6469,
#     'y0': 62.472,
#     'x1': 21.37,
#     'y1': 62.2786,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.5044,
#     'y0': 63.3875,
#     'x1': 22.5718,
#     'y1': 63.4455,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.0343,
#     'y0': 64.2056,
#     'x1': 23.6509,
#     'y1': 64.0415,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.346,
#     'y0': 66.2708,
#     'x1': 25.6426,
#     'y1': 65.4094,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.345,
#     'y0': 66.2698,
#     'x1': 25.5418,
#     'y1': 66.4251,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.346,
#     'y0': 66.2708,
#     'x1': 27.1443,
#     'y1': 66.3405,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.1433,
#     'y0': 66.3395,
#     'x1': 26.6872,
#     'y1': 66.3696,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.1433,
#     'y0': 66.3395,
#     'x1': 27.3199,
#     'y1': 67.225,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.5585,
#     'y0': 65.8205,
#     'x1': 27.1443,
#     'y1': 66.3405,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.8019,
#     'y0': 67.6954,
#     'x1': 27.3199,
#     'y1': 67.225,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9186,
#     'y0': 67.5279,
#     'x1': 25.7354,
#     'y1': 67.6256,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.7354,
#     'y0': 67.6256,
#     'x1': 26.8019,
#     'y1': 67.6954,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9186,
#     'y0': 67.5279,
#     'x1': 25.2036,
#     'y1': 66.9913,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.5418,
#     'y0': 66.4251,
#     'x1': 25.2036,
#     'y1': 66.9913,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.2273,
#     'y0': 69.8435,
#     'x1': 27.9698,
#     'y1': 70.0664,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.0891,
#     'y0': 69.9063,
#     'x1': 27.2273,
#     'y1': 69.8435,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 28.0302,
#     'y0': 61.0187,
#     'x1': 27.3892,
#     'y1': 61.6199,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.9492,
#     'y0': 60.7517,
#     'x1': 24.6991,
#     'y1': 60.7594,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.2446,
#     'y0': 60.7742,
#     'x1': 23.5752,
#     'y1': 60.8014,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 22.7102,
#     'y0': 62.7865,
#     'x1': 21.9695,
#     'y1': 61.7097,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 23.5105,
#     'y0': 63.974,
#     'x1': 23.6509,
#     'y1': 64.0415,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.5495,
#     'y0': 60.2046,
#     'x1': 24.6665,
#     'y1': 60.2287,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.6944,
#     'y0': 65.2668,
#     'x1': 25.7399,
#     'y1': 64.9249,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.6426,
#     'y0': 65.4094,
#     'x1': 25.6944,
#     'y1': 65.2668,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.0343,
#     'y0': 64.2056,
#     'x1': 24.233,
#     'y1': 64.2865,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.2954,
#     'y0': 63.8066,
#     'x1': 25.4525,
#     'y1': 64.1237,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.5733,
#     'y0': 64.2463,
#     'x1': 26.0492,
#     'y1': 64.8478,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.1438,
#     'y0': 62.2794,
#     'x1': 25.0951,
#     'y1': 62.8011,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.4525,
#     'y0': 64.1237,
#     'x1': 25.5733,
#     'y1': 64.2463,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.4515,
#     'y0': 64.1227,
#     'x1': 25.5723,
#     'y1': 64.2453,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.7399,
#     'y0': 64.9249,
#     'x1': 25.4975,
#     'y1': 64.693,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.4975,
#     'y0': 64.693,
#     'x1': 25.0679,
#     'y1': 64.681,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.0492,
#     'y0': 64.8478,
#     'x1': 25.4975,
#     'y1': 64.693,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.0492,
#     'y0': 64.8478,
#     'x1': 26.187,
#     'y1': 64.7836,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.3663,
#     'y0': 61.7279,
#     'x1': 27.3892,
#     'y1': 61.6199,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.1231,
#     'y0': 66.1549,
#     'x1': 24.8927,
#     'y1': 66.1426,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.233,
#     'y0': 64.2865,
#     'x1': 24.5621,
#     'y1': 64.4237,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.8908,
#     'y0': 59.6507,
#     'x1': 10.8171,
#     'y1': 59.5758,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.8702,
#     'y0': 59.9314,
#     'x1': 10.9065,
#     'y1': 60.1253,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.9049,
#     'y0': 59.9886,
#     'x1': 10.8702,
#     'y1': 59.9314,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.7453,
#     'y0': 59.5179,
#     'x1': 11.1564,
#     'y1': 59.3154,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.8322,
#     'y0': 59.7234,
#     'x1': 10.6364,
#     'y1': 59.5799,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.5658,
#     'y0': 60.7888,
#     'x1': 8.21,
#     'y1': 60.6211,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.4191,
#     'y0': 63.3267,
#     'x1': 10.445,
#     'y1': 63.3936,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.3471,
#     'y0': 60.5709,
#     'x1': 11.2838,
#     'y1': 60.4726,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.6595,
#     'y0': 58.9488,
#     'x1': 5.7503,
#     'y1': 58.8013,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.9755,
#     'y0': 60.7012,
#     'x1': 10.6959,
#     'y1': 59.9466,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.2156,
#     'y0': 59.8672,
#     'x1': 10.5091,
#     'y1': 59.903,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.5091,
#     'y0': 59.903,
#     'x1': 10.6959,
#     'y1': 59.9466,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.7453,
#     'y0': 59.5179,
#     'x1': 10.6374,
#     'y1': 59.5809,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.7443,
#     'y0': 59.5169,
#     'x1': 10.6364,
#     'y1': 59.5799,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.7443,
#     'y0': 59.5169,
#     'x1': 10.8171,
#     'y1': 59.5758,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.7453,
#     'y0': 59.5179,
#     'x1': 10.783,
#     'y1': 59.7289,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.3343,
#     'y0': 59.3792,
#     'x1': 5.4737,
#     'y1': 59.7301,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.3343,
#     'y0': 59.3792,
#     'x1': 5.3426,
#     'y1': 59.3195,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 15.4403,
#     'y0': 67.104,
#     'x1': 13.8835,
#     'y1': 66.7698,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.7503,
#     'y0': 58.8013,
#     'x1': 5.9201,
#     'y1': 58.5903,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.2156,
#     'y0': 59.8672,
#     'x1': 10.5091,
#     'y1': 59.903,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.2905,
#     'y0': 65.852,
#     'x1': 13.784,
#     'y1': 66.0518,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.9025,
#     'y0': 61.1375,
#     'x1': 7.0358,
#     'y1': 61.1808,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.3017,
#     'y0': 60.8614,
#     'x1': 7.0358,
#     'y1': 61.1808,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.9025,
#     'y0': 61.1375,
#     'x1': 6.6062,
#     'y1': 61.068,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.4712,
#     'y0': 59.362,
#     'x1': 5.5286,
#     'y1': 59.2759,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.3997,
#     'y0': 59.6608,
#     'x1': 6.1341,
#     'y1': 59.7831,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.5286,
#     'y0': 59.2759,
#     'x1': 5.6219,
#     'y1': 59.431,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.4131,
#     'y0': 59.7872,
#     'x1': 5.4737,
#     'y1': 59.7301,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.1327,
#     'y0': 60.0056,
#     'x1': 11.3259,
#     'y1': 60.2419,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.1564,
#     'y0': 59.3154,
#     'x1': 11.4156,
#     'y1': 59.1239,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 18.5864,
#     'y0': 69.0316,
#     'x1': 19.2043,
#     'y1': 69.1898,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.5743,
#     'y0': 66.6051,
#     'x1': 14.1668,
#     'y1': 66.3751,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.4765,
#     'y0': 59.1286,
#     'x1': 9.4434,
#     'y1': 59.226,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.4434,
#     'y0': 59.226,
#     'x1': 9.5518,
#     'y1': 59.2767,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.342,
#     'y0': 60.2872,
#     'x1': 5.457,
#     'y1': 60.3946,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.9792,
#     'y0': 60.3563,
#     'x1': 6.1948,
#     'y1': 60.2579,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.5031,
#     'y0': 63.7526,
#     'x1': 12.8371,
#     'y1': 64.7039,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.5041,
#     'y0': 63.7536,
#     'x1': 11.621,
#     'y1': 64.0279,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.8835,
#     'y0': 66.7698,
#     'x1': 13.5869,
#     'y1': 66.7033,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.4156,
#     'y0': 59.1239,
#     'x1': 11.6232,
#     'y1': 58.9055,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.559,
#     'y0': 68.1588,
#     'x1': 17.7391,
#     'y1': 68.434,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.7443,
#     'y0': 59.5169,
#     'x1': 11.1554,
#     'y1': 59.3144,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 12.7944,
#     'y0': 65.2068,
#     'x1': 13.2258,
#     'y1': 64.9867,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.621,
#     'y0': 64.0279,
#     'x1': 11.7763,
#     'y1': 64.4782,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.3736,
#     'y0': 59.276,
#     'x1': 7.2492,
#     'y1': 59.3458,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 4.9691,
#     'y0': 60.4394,
#     'x1': 5.1579,
#     'y1': 60.364,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.9578,
#     'y0': 59.2392,
#     'x1': 9.1241,
#     'y1': 59.2136,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.032,
#     'y0': 58.495,
#     'x1': 6.4538,
#     'y1': 58.2952,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.7503,
#     'y0': 58.8013,
#     'x1': 6.7277,
#     'y1': 58.6584,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.0855,
#     'y0': 59.0256,
#     'x1': 7.0885,
#     'y1': 58.9307,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.018,
#     'y0': 58.7696,
#     'x1': 7.0885,
#     'y1': 58.9307,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.895,
#     'y0': 59.1257,
#     'x1': 7.0855,
#     'y1': 59.0256,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.7287,
#     'y0': 58.6594,
#     'x1': 6.8614,
#     'y1': 58.2745,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.6538,
#     'y0': 59.0601,
#     'x1': 6.2949,
#     'y1': 59.0068,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.8027,
#     'y0': 63.2461,
#     'x1': 10.4191,
#     'y1': 63.3267,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.3997,
#     'y0': 59.6608,
#     'x1': 6.8198,
#     'y1': 59.6514,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.6408,
#     'y0': 59.5412,
#     'x1': 6.6755,
#     'y1': 59.485,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.9969,
#     'y0': 59.8522,
#     'x1': 6.1341,
#     'y1': 59.7831,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.6033,
#     'y0': 59.3274,
#     'x1': 8.0207,
#     'y1': 59.4514,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.019,
#     'y0': 58.7706,
#     'x1': 7.4764,
#     'y1': 58.6809,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.5883,
#     'y0': 60.1258,
#     'x1': 6.838,
#     'y1': 59.8248,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.8198,
#     'y0': 59.6514,
#     'x1': 6.838,
#     'y1': 59.8248,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.0207,
#     'y0': 59.4514,
#     'x1': 8.9223,
#     'y1': 59.5583,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.5767,
#     'y0': 60.4376,
#     'x1': 8.9502,
#     'y1': 60.2652,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.4123,
#     'y0': 60.5751,
#     'x1': 8.5767,
#     'y1': 60.4376,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.9502,
#     'y0': 60.2652,
#     'x1': 10.2166,
#     'y1': 59.8682,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.0207,
#     'y0': 59.4514,
#     'x1': 7.9019,
#     'y1': 59.5453,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.7252,
#     'y0': 59.7751,
#     'x1': 7.8518,
#     'y1': 59.625,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.439,
#     'y0': 58.4855,
#     'x1': 8.6049,
#     'y1': 58.5231,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.259,
#     'y0': 58.9242,
#     'x1': 9.1811,
#     'y1': 58.8611,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.8322,
#     'y0': 59.7234,
#     'x1': 10.1051,
#     'y1': 59.5766,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.6596,
#     'y0': 59.7164,
#     'x1': 9.8322,
#     'y1': 59.7234,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.4131,
#     'y0': 59.7872,
#     'x1': 5.5253,
#     'y1': 59.8915,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.9969,
#     'y0': 59.8522,
#     'x1': 6.278,
#     'y1': 60.1269,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.0813,
#     'y0': 61.8813,
#     'x1': 9.3126,
#     'y1': 61.4831,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.7265,
#     'y0': 61.3988,
#     'x1': 9.5324,
#     'y1': 61.4545,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.9681,
#     'y0': 61.4017,
#     'x1': 9.8867,
#     'y1': 61.4914,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.6264,
#     'y0': 62.8462,
#     'x1': 9.8027,
#     'y1': 63.2461,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.6274,
#     'y0': 62.8472,
#     'x1': 8.4998,
#     'y1': 62.7102,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.4988,
#     'y0': 62.7092,
#     'x1': 8.6264,
#     'y1': 62.8462,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.8322,
#     'y0': 59.7234,
#     'x1': 10.2156,
#     'y1': 59.8672,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.1564,
#     'y0': 59.3154,
#     'x1': 10.663,
#     'y1': 59.3653,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.1481,
#     'y0': 60.249,
#     'x1': 10.1986,
#     'y1': 60.1705,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.3027,
#     'y0': 60.8624,
#     'x1': 7.3373,
#     'y1': 60.6234,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.5767,
#     'y0': 60.4376,
#     'x1': 10.1986,
#     'y1': 60.1705,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.3027,
#     'y0': 60.8624,
#     'x1': 7.3663,
#     'y1': 60.8099,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.3663,
#     'y0': 60.8099,
#     'x1': 7.5658,
#     'y1': 60.7888,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.1051,
#     'y0': 59.5766,
#     'x1': 10.3817,
#     'y1': 59.3297,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.3961,
#     'y0': 59.9308,
#     'x1': 5.5253,
#     'y1': 59.8915,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.6114,
#     'y0': 68.5774,
#     'x1': 18.1254,
#     'y1': 68.7784,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
# ...
#     'y1': 58.8442,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.783,
#     'y0': 66.0508,
#     'x1': 14.5891,
#     'y1': 65.7639,
#     'line': {'color': 'rosybrown', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 26.0482,
#     'y0': 64.8468,
#     'x1': 26.0492,
#     'y1': 64.8478,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.4515,
#     'y0': 64.1227,
#     'x1': 25.4525,
#     'y1': 64.1237,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.345,
#     'y0': 66.2698,
#     'x1': 25.346,
#     'y1': 66.2708,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.369,
#     'y0': 62.2776,
#     'x1': 21.37,
#     'y1': 62.2786,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 27.1433,
#     'y0': 66.3395,
#     'x1': 27.1443,
#     'y1': 66.3405,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.7443,
#     'y0': 59.5169,
#     'x1': 10.7453,
#     'y1': 59.5179,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.3817,
#     'y0': 59.3297,
#     'x1': 10.3827,
#     'y1': 59.3307,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.1554,
#     'y0': 59.3144,
#     'x1': 11.1564,
#     'y1': 59.3154,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.7503,
#     'y0': 58.8013,
#     'x1': 5.7513,
#     'y1': 58.8023,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.6299,
#     'y0': 59.0831,
#     'x1': 9.6309,
#     'y1': 59.0841,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.6364,
#     'y0': 59.5799,
#     'x1': 10.6374,
#     'y1': 59.5809,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.2156,
#     'y0': 59.8672,
#     'x1': 10.2166,
#     'y1': 59.8682,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.4988,
#     'y0': 62.7092,
#     'x1': 8.4998,
#     'y1': 62.7102,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.5508,
#     'y0': 59.2757,
#     'x1': 9.5518,
#     'y1': 59.2767,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.5031,
#     'y0': 63.7526,
#     'x1': 11.5041,
#     'y1': 63.7536,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.8322,
#     'y0': 59.7234,
#     'x1': 9.8332,
#     'y1': 59.7244,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.4191,
#     'y0': 63.3267,
#     'x1': 10.4201,
#     'y1': 63.3277,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.7252,
#     'y0': 59.7751,
#     'x1': 7.7262,
#     'y1': 59.7761,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.3997,
#     'y0': 59.6608,
#     'x1': 6.4007,
#     'y1': 59.6618,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.1327,
#     'y0': 60.0056,
#     'x1': 11.1337,
#     'y1': 60.0066,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.4113,
#     'y0': 60.5741,
#     'x1': 8.4123,
#     'y1': 60.5751,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 5.8506,
#     'y0': 60.4017,
#     'x1': 5.8516,
#     'y1': 60.4027,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.0358,
#     'y0': 61.1808,
#     'x1': 7.0368,
#     'y1': 61.1818,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.018,
#     'y0': 58.7696,
#     'x1': 7.019,
#     'y1': 58.7706,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.9872,
#     'y0': 59.4937,
#     'x1': 17.9882,
#     'y1': 59.4947,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 18.0275,
#     'y0': 59.3891,
#     'x1': 18.0285,
#     'y1': 59.3901,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.7026,
#     'y0': 59.2023,
#     'x1': 17.7036,
#     'y1': 59.2033,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 18.0699,
#     'y0': 59.2626,
#     'x1': 18.0709,
#     'y1': 59.2636,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.8533,
#     'y0': 59.6874,
#     'x1': 17.8543,
#     'y1': 59.6884,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.8918,
#     'y0': 59.6172,
#     'x1': 17.8928,
#     'y1': 59.6182,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 15.1051,
#     'y0': 59.2758,
#     'x1': 15.1061,
#     'y1': 59.2768,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 18.052,
#     'y0': 59.9614,
#     'x1': 18.053,
#     'y1': 59.9624,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 15.2551,
#     'y0': 63.2327,
#     'x1': 15.2561,
#     'y1': 63.2337,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.3858,
#     'y0': 63.3891,
#     'x1': 13.3868,
#     'y1': 63.3901,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.3868,
#     'y0': 63.3901,
#     'x1': 13.3878,
#     'y1': 63.3911,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.3878,
#     'y0': 63.3911,
#     'x1': 13.3888,
#     'y1': 63.3921,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.2419,
#     'y0': 59.7318,
#     'x1': 17.2429,
#     'y1': 59.7328,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.0519,
#     'y0': 63.1691,
#     'x1': 17.0529,
#     'y1': 63.1701,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 14.9197,
#     'y0': 59.0291,
#     'x1': 14.9207,
#     'y1': 59.0301,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 18.1001,
#     'y0': 59.183,
#     'x1': 18.1011,
#     'y1': 59.184,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.7935,
#     'y0': 63.5454,
#     'x1': 16.7945,
#     'y1': 63.5464,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.7792,
#     'y0': 63.6345,
#     'x1': 16.7802,
#     'y1': 63.6355,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.9414,
#     'y0': 62.3707,
#     'x1': 16.9424,
#     'y1': 62.3717,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.5795,
#     'y0': 64.9644,
#     'x1': 17.5805,
#     'y1': 64.9654,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 15.678,
#     'y0': 62.5162,
#     'x1': 15.679,
#     'y1': 62.5172,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.6845,
#     'y0': 63.2989,
#     'x1': 13.6855,
#     'y1': 63.2999,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.3017,
#     'y0': 60.8614,
#     'x1': 7.3027,
#     'y1': 60.8624,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.9492,
#     'y0': 60.2642,
#     'x1': 8.9502,
#     'y1': 60.2652,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.9004,
#     'y0': 58.2597,
#     'x1': 7.9014,
#     'y1': 58.2607,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.8604,
#     'y0': 58.2735,
#     'x1': 6.8614,
#     'y1': 58.2745,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.783,
#     'y0': 66.0508,
#     'x1': 13.784,
#     'y1': 66.0518,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.784,
#     'y0': 66.0518,
#     'x1': 13.785,
#     'y1': 66.0528,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 12.8371,
#     'y0': 64.7039,
#     'x1': 12.8381,
#     'y1': 64.7049,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.6528,
#     'y0': 59.0591,
#     'x1': 6.6538,
#     'y1': 59.0601,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.7277,
#     'y0': 58.6584,
#     'x1': 6.7287,
#     'y1': 58.6594,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.6745,
#     'y0': 59.484,
#     'x1': 6.6755,
#     'y1': 59.485,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.9847,
#     'y0': 60.603,
#     'x1': 16.9857,
#     'y1': 60.604,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.7245,
#     'y0': 58.8432,
#     'x1': 11.7255,
#     'y1': 58.8442,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.7008,
#     'y0': 62.8008,
#     'x1': 16.7018,
#     'y1': 62.8018,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 14.6401,
#     'y0': 62.4904,
#     'x1': 14.6411,
#     'y1': 62.4914,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 14.1363,
#     'y0': 58.7219,
#     'x1': 14.1373,
#     'y1': 58.7229,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 14.1688,
#     'y0': 63.3245,
#     'x1': 14.1698,
#     'y1': 63.3255,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.0131,
#     'y0': 61.3706,
#     'x1': 16.0141,
#     'y1': 61.3716,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.0497,
#     'y0': 61.3215,
#     'x1': 16.0507,
#     'y1': 61.3225,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.8873,
#     'y0': 62.5444,
#     'x1': 16.8883,
#     'y1': 62.5454,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.9174,
#     'y0': 62.4439,
#     'x1': 16.9184,
#     'y1': 62.4449,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.201,
#     'y0': 60.525,
#     'x1': 17.202,
#     'y1': 60.526,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.5723,
#     'y0': 64.2453,
#     'x1': 25.5733,
#     'y1': 64.2463,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.6264,
#     'y0': 62.8462,
#     'x1': 8.6274,
#     'y1': 62.8472,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 9.023,
#     'y0': 59.7853,
#     'x1': 9.024,
#     'y1': 59.7863,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 10.9049,
#     'y0': 59.9886,
#     'x1': 10.9059,
#     'y1': 59.9896,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 11.8172,
#     'y0': 59.3375,
#     'x1': 11.8182,
#     'y1': 59.3385,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 12.0596,
#     'y0': 63.1767,
#     'x1': 12.0606,
#     'y1': 63.1777,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.9907,
#     'y0': 63.3402,
#     'x1': 13.9917,
#     'y1': 63.3412,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.4645,
#     'y0': 68.0817,
#     'x1': 17.4655,
#     'y1': 68.0827,
#     'line': {'color': 'orange', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 18.1942,
#     'y0': 57.5871,
#     'x1': 16.6493,
#     'y1': 57.7288,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.6016,
#     'y0': 55.8313,
#     'x1': 14.6554,
#     'y1': 57.7478,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6262,
#     'y0': 61.1532,
#     'x1': 17.0626,
#     'y1': 60.4258,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 18.1358,
#     'y0': 60.4043,
#     'x1': 21.6252,
#     'y1': 61.1522,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 16.6493,
#     'y0': 57.7288,
#     'x1': 16.6585,
#     'y1': 57.4159,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.6016,
#     'y0': 55.8313,
#     'x1': 13.6026,
#     'y1': 55.832,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 14.6554,
#     'y0': 57.7478,
#     'x1': 14.6586,
#     'y1': 57.7517,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 13.147,
#     'y0': 55.5014,
#     'x1': 13.1456,
#     'y1': 55.5017,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.8684,
#     'y0': 58.2825,
#     'x1': 6.8614,
#     'y1': 58.2745,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.7549,
#     'y0': 58.6704,
#     'x1': 6.7287,
#     'y1': 58.6594,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 7.9019,
#     'y0': 58.261,
#     'x1': 7.9014,
#     'y1': 58.2607,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 12.1106,
#     'y0': 57.6082,
#     'x1': 12.1116,
#     'y1': 57.607,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 8.0423,
#     'y0': 58.2213,
#     'x1': 7.9014,
#     'y1': 58.2607,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 25.3686,
#     'y0': 60.3765,
#     'x1': 25.3681,
#     'y1': 60.3773,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 24.5513,
#     'y0': 60.2038,
#     'x1': 24.5495,
#     'y1': 60.2046,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6262,
#     'y0': 61.1532,
#     'x1': 21.6301,
#     'y1': 61.1808,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 17.0626,
#     'y0': 60.4258,
#     'x1': 17.0609,
#     'y1': 60.4249,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 18.1358,
#     'y0': 60.4043,
#     'x1': 18.155,
#     'y1': 60.3989,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 21.6252,
#     'y0': 61.1522,
#     'x1': 21.6301,
#     'y1': 61.1808,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 6.653,
#     'y0': 59.5307,
#     'x1': 6.6408,
#     'y1': 59.5412,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 15.855,
#     'y0': 56.7682,
#     'x1': 15.8572,
#     'y1': 56.7671,
#     'line': {'color': 'darkseagreen', 'width': 3}},
#    {'type': 'line',
#     'opacity': 0.8,
#     'x0': 14.8414,
#     'y0': 56.1533,
#     'x1': 14.8371,
#     'y1': 56.1525,
#     'line': {'color': 'darkseagreen', 'width': 3}}]}}
